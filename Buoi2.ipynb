# %% [markdown]
# # Bài tập buổi 2:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
with open(file="E:\Downloads\Iris.csv", mode = 'r') as csv_file:
    data = csv_file.readlines()
text = data[1:]
for i in range(len(text)):
    text[i] = text[i].split(",")
    print(text[i])
print(type(text))
# Out:
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa\n']
# ['2', '4.9', '3.0', '1.4', '0.2', 'Iris-setosa\n']
# ['3', '4.7', '3.2', '1.3', '0.2', 'Iris-setosa\n']
# ['4', '4.6', '3.1', '1.5', '0.2', 'Iris-setosa\n']
# ['5', '5.0', '3.6', '1.4', '0.2', 'Iris-setosa\n']
# ['6', '5.4', '3.9', '1.7', '0.4', 'Iris-setosa\n']
# ['7', '4.6', '3.4', '1.4', '0.3', 'Iris-setosa\n']
# ['8', '5.0', '3.4', '1.5', '0.2', 'Iris-setosa\n']
# ['9', '4.4', '2.9', '1.4', '0.2', 'Iris-setosa\n']
# ['10', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa\n']
# ['11', '5.4', '3.7', '1.5', '0.2', 'Iris-setosa\n']
# ['12', '4.8', '3.4', '1.6', '0.2', 'Iris-setosa\n']
# ['13', '4.8', '3.0', '1.4', '0.1', 'Iris-setosa\n']
# ['14', '4.3', '3.0', '1.1', '0.1', 'Iris-setosa\n']
# ['15', '5.8', '4.0', '1.2', '0.2', 'Iris-setosa\n']
# ['16', '5.7', '4.4', '1.5', '0.4', 'Iris-setosa\n']
# ['17', '5.4', '3.9', '1.3', '0.4', 'Iris-setosa\n']
# ['18', '5.1', '3.5', '1.4', '0.3', 'Iris-setosa\n']
# ...

# %%
# 1a,2a

# Tổng chiều dài và chiều rộng của từng loại hoa theo list
sum_list = [0,0,0,0,0,0]
# Chiều dài, chiều rộng lớn nhất của từng loại hoa theo list
max_iris = [0,0,0,0,0,0]
# Bộ đếm từng loại hoa theo list
i = [0,0,0]

# Chạy từng dòng của text:
for s in text:
    # Đổi type cho chiều dài, chiều rộng của đài hoa thành float
    x = float(s[1])
    y = float(s[2])
    
    if s[5] == 'Iris-setosa\n':
        i[0]+=1
        sum_list[0] += x
        sum_list[1] += y
        # 2a, So sánh chiều dài, chiều rộng, lấy max từng loại
        if max_iris[0] < x:
            max_iris[0] = x
        if max_iris[1] < y:
            max_iris[1] = y
        
    elif s[5] == 'Iris-versicolor\n':
        i[1] +=1
        sum_list[2] += x
        sum_list[3] += y
        # 2a, So sánh chiều dài, chiều rộng, lấy max từng loại
        if max_iris[2] < x:
            max_iris[2] = x
        if max_iris[3] < y:
            max_iris[3] = y
        
    else:
        i[2] +=1
        sum_list[4] += x
        sum_list[5] += y
        # 2a, So sánh chiều dài, chiều rộng, lấy max từng loại
        if max_iris[4] < x:
            max_iris[4] = x
        if max_iris[5] < y:
            max_iris[5] = y

print("Trung bình cộng chiều dài Iris-sentosa: ", sum_list[0] / i[0])
print("Trung bình cộng chiều rộng Iris-sentosa: ", sum_list[1] / i[0])
print("Trung bình cộng chiều dài Iris-versicolor: ", sum_list[2] / i[1])
print("Trung bình cộng chiều rộng Iris-versicolor: ", sum_list[3] / i[1])
print("Trung bình cộng chiều dài Iris-virginica: ", sum_list[4] / i[2])
print("Trung bình cộng chiều rộng Iris-virginica: ", sum_list[5] / i[2])

print("Chiều dài lớn nhất của Iris-sentosa: ", max_iris[0])
print("Chiều rộng lớn nhất của Iris-sentosa: ", max_iris[1])
print("Chiều dài lớn nhất của Iris-versicolor: ", max_iris[2])
print("Chiều rộng lớn nhất của Iris-versicolor: ", max_iris[3])
print("Chiều dài lớn nhất của Iris-virginica: ", max_iris[4])
print("Chiều rộng lớn nhất của Iris-virginica: ", max_iris[5])


# text = data[1:]
# for i in range(len(text)):
#     text[i] = text[i].split(",")    

# sum_setosa_length=0
# sum_setosa_width=0
# sum_versicolor_length=0
# sum_versicolor_width=0
# sum_virginica_length=0
# sum_virginica_width=0
# n=50

# for s in text:
#     s[1] = float(s[1])
#     s[2] = float(s[2])
#     if s[5] == 'Iris-setosa\n':
#         sum_setosa_length += s[1]
#         sum_setosa_width += s[2]
#     elif s[5] == 'Iris-versicolor\n':
#         sum_versicolor_length += s[1]
#         sum_versicolor_width += s[2]
#     else:
#         sum_virginica_length += s[1]
#         sum_virginica_width += s[2]

# print(round(sum_setosa_length,1))
# print(round(sum_setosa_width,1))
# print(round(sum_versicolor_length,1))
# print(round(sum_versicolor_width,1))
# print(round(sum_virginica_length,1))
# print(round(sum_virginica_width,1))


# sum_sepal_length=0
# for s in text[100:150]:
#     s[2] = float(s[2])
#     sum_sepal_length += s[2]
# print(sum_sepal_length)

# for row in data[1:]:
#     text = row.split(",")

# chieu_dai = []
# for row in data[1:51]:
#     text = row.split(",")
#     chieu_dai.append(text[1])
# sum1 = 0
# for i in range(0,50):
#     chieu_dai[i] = float(chieu_dai[i])
#     sum1 += chieu_dai[i]
# print(round(sum1,2))



# chieu_dai = []
# for row in text[0:50]:
#     chieu_dai.append(row[1])
# sum1 = 0
# for i in range(0,50):
#     chieu_dai[i] = float(chieu_dai[i])
#     sum1 += chieu_dai[i]
# print(round(sum1,2))
# Out:
# Trung bình cộng chiều dài Iris-sentosa:  5.005999999999999
# Trung bình cộng chiều rộng Iris-sentosa:  3.4180000000000006
# Trung bình cộng chiều dài Iris-versicolor:  5.936
# Trung bình cộng chiều rộng Iris-versicolor:  2.7700000000000005
# Trung bình cộng chiều dài Iris-virginica:  6.587999999999998
# Trung bình cộng chiều rộng Iris-virginica:  2.9739999999999998
# Chiều dài lớn nhất của Iris-sentosa:  5.8
# Chiều rộng lớn nhất của Iris-sentosa:  4.4
# Chiều dài lớn nhất của Iris-versicolor:  7.0
# Chiều rộng lớn nhất của Iris-versicolor:  3.4
# Chiều dài lớn nhất của Iris-virginica:  7.9
# Chiều rộng lớn nhất của Iris-virginica:  3.8

# %%
# 3a.1,

length_flower = float(input())
width_flower = float(input())
d_min = 1000
count=0
def euclit(a1,b1,a2,b2):
    d = (a1-a2)**2 + (b1-b2)**2
    return d
for s in text:
    count+=1
    # Đổi type cho chiều dài, chiều rộng của đài hoa thành float
    x = float(s[1])
    y = float(s[2])
    d = euclit(length_flower,width_flower,x,y)
    if d < d_min:
        count_min = count
        d_min = d
print("d_min: ",d_min)
print("Chỉ số: ",count_min)
if count_min <= i[0]:
    print("3a.1, Bông hoa thuộc loại hoa Iris-setosa")
elif count <= i[0]+i[1]:
    print("3a.1, Bông hoa thuộc loại hoa Iris-versicolor")
else:
    print("3a.1, Bông hoa thuộc loại hoa Iris-virginica")
    
# 3a.2,
# Trung bình cộng chiều dài, chiều rộng từng loại hoa theo list
average_list = [0,0,0,0,0,0]

for a in range (0,6):
    average_list[a] = sum_list[a] / i[round(a/2)]
d_aver_set = euclit(length_flower,width_flower,average_list[0],average_list[1])
d_aver_ver = euclit(length_flower,width_flower,average_list[2],average_list[3])
d_aver_vir = euclit(length_flower,width_flower,average_list[4],average_list[5])
d2_min = min(d_aver_set,d_aver_ver,d_aver_vir)
print("d_aver_set: ",d_aver_set)
print("d_aver_ver: ",d_aver_ver)
print("d_aver_vir: ",d_aver_vir)


if d2_min == d_aver_set:
    print("3a.2, Bông hoa thuộc loại hoa Iris-setosa")
elif d2_min == d_aver_ver:
    print("3a.2, Bông hoa thuộc loại hoa Iris-versicolor")
else:
    print("3a.2, Bông hoa thuộc loại hoa Iris-virginica")
# Out:
# 4
# 3.4
# d_min:  0.20000000000000018
# Chỉ số:  43
# 3a.1, Bông hoa thuộc loại hoa Iris-setosa
# d_aver_set:  1.0123599999999986
# d_aver_ver:  4.144995999999999
# d_aver_vir:  6.879219999999991
# 3a.2, Bông hoa thuộc loại hoa Iris-setosa

# %%
# 1b,

for a in range (0,6):
    average_list[a] = sum_list[a] / i[round(a/2)]
print(average_list)
# Out:
# [5.005999999999999, 3.4180000000000006, 5.936, 2.7700000000000005, 6.587999999999998, 2.9739999999999998]

# %%
250.29999999999998
170.90000000000003
296.8
138.50000000000003
329.3999999999999
148.7
